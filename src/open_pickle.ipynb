# %%
import pickle
import cv2
import numpy as np
import matplotlib.pyplot as plt

with open('jestin_video_1.pkl', 'rb') as f:
    data = pickle.load(f)

rgb_frames = data['rgb_frames']
height_frames = data['height_frames']

print(height_frames[0])
# plt.imshow(height_frames[0], cmap="jet")
print(data.keys())
# plt.imshow(rgb_frames[0])
# for rgb, height in zip(rgb_frames, height_frames):
#     cv2.imshow('RGB', rgb)
#     cv2.imshow('Height Map', height)
#     if cv2.waitKey(30) & 0xFF == ord('q'):  # 30 ms for ~30 FPS
#         break
# cv2.destroyAllWindows()
# Out:
# [[      nan       nan       nan ... 3.301     3.301     3.3230002]
#  [      nan       nan       nan ... 3.2800002 3.2800002 3.301    ]
#  [      nan       nan       nan ... 3.2700002 3.2700002 3.2910001]
#  ...
#  [      nan       nan       nan ...       nan       nan       nan]
#  [      nan       nan       nan ...       nan       nan       nan]
#  [      nan       nan       nan ...       nan       nan       nan]]
# dict_keys(['rgb_frames', 'height_frames', 'timestamps', 'depth_scale', 'frame_shape', 'height_shape', 'num_frames', 'start_time', 'end_time'])
